# %% [markdown]
# <b><h4>HW3 - Notebook: Multi-Layer perceptron</h4></b>
#
# [CE40477: Machine Learning](https://www.sharifml.ir/)
#
# __Course Instructor__: Dr. Sharifi-Zarchi
#
# __Notebook Authors__: Amir Ezzati & Ali Bavafa
#
# Name: Sadegh Mohammadian
# Student-ID: 401109477

# %% [markdown]
# # Import & Helper Functions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gdown
from sklearn.datasets import fetch_openml
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import time
import random

import torch
import torch.nn as nn
import torch.optim as optim

from torchvision import transforms
from torchvision.utils import make_grid
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, TensorDataset

from tqdm.auto import tqdm
from IPython.display import display

# %%
def seed_setter(seed=None, seed_torch=True):
  """
  Function that controls randomness.

  Args:
    seed : Integer
      A non-negative integer that defines the random state.
    seed_torch : Boolean
      If `True` sets the random seed for pytorch tensors.

  Returns:
    Nothing.
  """
  if seed is None:
    seed = np.random.choice(2 ** 32)
  random.seed(seed)
  np.random.seed(seed)
  if seed_torch:
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

  print(f'Random seed {seed} has been set.')


# In case that `DataLoader` is used
def seed_worker(worker_id):

  worker_seed = torch.initial_seed() % 2**32
  np.random.seed(worker_seed)
  random.seed(worker_seed)


def train_test_classification(net, criterion, optimizer, train_loader,
                              test_loader, num_epochs=1, verbose=True,
                              training_plot=False):
  """
  Accumulate training loss/Evaluate performance

  Args:
    net: Instance of Net class
      Describes the model with ReLU activation, batch size 128
    criterion: torch.nn type
      Criterion combines LogSoftmax and NLLLoss in one single class.
    optimizer: torch.optim type
      Implements Adam algorithm.
    train_loader: torch.utils.data type
      Combines the train dataset and sampler, and provides an iterable over the given dataset.
    test_loader: torch.utils.data type
      Combines the test dataset and sampler, and provides an iterable over the given dataset.
    num_epochs: int
      Number of epochs [default: 1]
    verbose: boolean
      If True, print statistics
    training_plot=False
      If True, display training plot

  Returns:
    Nothing
  """
  net.train()
  train_losses = []
  for epoch in tqdm(range(num_epochs)):
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
      # Get the inputs; data is a list of [inputs, labels]
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      optimizer.zero_grad()
      outputs = net(inputs)

      loss = criterion(outputs, labels)
      loss.backward()
      optimizer.step()

      if verbose:
        train_losses += [loss.item()]

  net.eval()

  def test(data_loader):
    """
    Function to gauge network performance

    Args:
      data_loader: torch.utils.data type
        Combines the test dataset and sampler, and provides an iterable over the given dataset.

    Returns:
      acc: float
        Performance of the network
      total: int
        Number of datapoints in the dataloader
    """
    correct = 0
    total = 0
    for data in data_loader:
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      outputs = net(inputs)
      _, predicted = torch.max(outputs, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

    acc = 100 * correct / total
    return total, acc

  train_total, train_acc = test(train_loader)
  test_total, test_acc = test(test_loader)

  if verbose:
    print(f'\nAccuracy on the {train_total} training samples: {train_acc:0.2f}')
    print(f'Accuracy on the {test_total} testing samples: {test_acc:0.2f}\n')

  if training_plot:
    plt.plot(train_losses)
    plt.xlabel('Batch')
    plt.ylabel('Training loss')
    plt.show()

  return train_acc, test_acc


def shuffle_and_split_data(X, y, seed):
  """
  Helper function to shuffle and split data

  Args:
    X: torch.tensor
      Input data
    y: torch.tensor
      Corresponding target variables
    seed: int
      Set seed for reproducibility

  Returns:
    X_test: torch.tensor
      Test data [20% of X]
    y_test: torch.tensor
      Labels corresponding to above mentioned test data
    X_train: torch.tensor
      Train data [80% of X]
    y_train: torch.tensor
      Labels corresponding to above mentioned train data
  """
  # Set seed for reproducibility
  torch.manual_seed(seed)
  # Number of samples
  N = X.shape[0]
  # Shuffle data
  shuffled_indices = torch.randperm(N)
  X = X[shuffled_indices]
  y = y[shuffled_indices]

  test_size = int(0.2 * N)
  X_test = X[:test_size]
  y_test = y[:test_size]
  X_train = X[test_size:]
  y_train = y[test_size:]

  return X_test, y_test, X_train, y_train


def sample_grid(M=500, x_max=2.0):
  """
  Helper function to simulate sample meshgrid

  Args:
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points

  Returns:
    X_all: torch.tensor
      Concatenated meshgrid tensor
  """
  ii, jj = torch.meshgrid(torch.linspace(-x_max, x_max,M),
                          torch.linspace(-x_max, x_max, M),
                          indexing='ij')
  X_all = torch.cat([ii.unsqueeze(-1),
                     jj.unsqueeze(-1)],
                     dim=-1).view(-1, 2)
  return X_all


def plot_decision_map(X_all, y_pred, X_test, y_test,
                      M=500, x_max=2.0, eps=1e-3):
  """
  Helper function to plot decision map

  Args:
    X_all: torch.tensor
      Concatenated meshgrid tensor
    y_pred: torch.tensor
      Labels predicted by the network
    X_test: torch.tensor
      Test data
    y_test: torch.tensor
      Labels of the test data
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points
    eps: float
      Decision threshold

  Returns:
    Nothing
  """
  decision_map = torch.argmax(y_pred, dim=1)

  for i in range(len(X_test)):
    indeces = (X_all[:, 0] - X_test[i, 0])**2 + (X_all[:, 1] - X_test[i, 1])**2 < eps
    decision_map[indeces] = (K + y_test[i]).long()

  decision_map = decision_map.view(M, M).cpu()
  plt.imshow(decision_map, extent=[-x_max, x_max, -x_max, x_max], cmap='jet')
  plt.axis('off')
  plt.plot()


def plot_function_apx(x_vals, relu_activations, predicted_output):
    """
    Visualizes ReLU activations and the resulting function approximation.

    Args:
      x_vals: torch.tensor
        Input x-axis data points.
      relu_activations: torch.tensor
        Calculated ReLU activations along x-axis for each ReLU unit.
      predicted_output: torch.tensor
        Estimated output labels or function approximations (weighted sum of ReLUs).

    Returns:
      None
    """

    fig, axes = plt.subplots(2, 1, figsize=(8, 6))

    ## Plot ReLU activations
    axes[0].plot(x_vals, relu_activations.T)
    axes[0].set_xlabel('x-values', fontsize=12)
    axes[0].set_ylabel('Activation Levels', fontsize=12)
    axes[0].set_title('ReLU Activations (Basis Functions)', fontsize=14)
    relu_labels = [f"ReLU {i + 1}" for i in range(relu_activations.shape[0])]
    axes[0].legend(relu_labels, ncol=2)

    ## Plot the function approximation and the ground truth
    axes[1].plot(x_vals, torch.sin(x_vals), label='Ground Truth (sin(x))', color='g', linewidth=2)
    axes[1].plot(x_vals, predicted_output, label='Predicted Output', linestyle='--', color='r')
    axes[1].set_xlabel('x-values', fontsize=12)
    axes[1].set_ylabel('y(x)', fontsize=12)
    axes[1].set_title('Function Approximation vs Ground Truth', fontsize=14)
    axes[1].legend()

    plt.tight_layout(pad=2)
    plt.show()


def show_images(image, num_row=2, num_col=5):
    # plot images
    image_size = int(np.sqrt(image.shape[-1]))
    image = np.reshape(image, (image.shape[0], image_size, image_size))
    fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
    for i in range(num_row*num_col):
        ax = axes[i//num_col, i%num_col]
        ax.imshow(image[i], cmap='gray', vmin=0, vmax=1)
        ax.axis('off')
    plt.tight_layout()
    plt.show()


SEED = 2024
# Call `seed_setter` to ensure reproducibility.
seed_setter(seed=SEED)
# Out:
# Random seed 2024 has been set.

# %% [markdown]
# # Loading the data

# %%
# Load data
mnist_data = fetch_openml("mnist_784")
x = mnist_data["data"].astype('float').to_numpy()
y = mnist_data["target"].astype('int')

# Normalize
x /= 255.0

# One-hot encode labels
num_labels = len(np.unique(y))
y_new = to_categorical(y, num_labels)

# -------------------------------- TODO -------------------------------------
# In this section, split the data into training and test datasets, using 60,000 samples for training and the remaining samples for testing.
x_train, x_test, y_train, y_test = train_test_split(x, y_new, test_size=10000 / len(x), random_state=SEED)


# -------------------------------- TODO -------------------------------------

# %%
print("Training data: {} {}".format(x_train.shape, y_train.shape))
print("Test data: {} {}".format(x_test.shape, y_test.shape))
show_images(x_train)
# Out:
# Training data: (60000, 784) (60000, 10)
# Test data: (10000, 784) (10000, 10)

# %% [markdown]
# # Activation Functions & Optimizers

# %% [markdown]
# There are many activation functions which some of them listed below. In this section you should implement them.
#
# 1. Sigmoid:
# $$
# \operatorname{sigmoid}(x) = \frac{1}{1 + \exp(-x)}
# $$
#
# 2. Softmax: $$\operatorname{softmax}(\mathbf X)_{ij} = \frac{\exp(\mathbf X_{ij})}{\sum_k \exp \mathbf X_{ik})}.$$
#
#
# 3. Tanh (Hyperbolic Tangent):
# $$
# \operatorname{tanh}(x) = \frac{\sinh(x)}{\cosh(x)} = \frac{\exp(x) - \exp(-x)}{\exp(x) + \exp(-x)}
# $$
#
# 4. ReLU: $$\operatorname{ReLU}(x) = \max(0, x)$$
#
# 5. Leaky ReLU:
# $$
# \operatorname{LeakyReLU}(x) =
# \begin{cases}
# x & \text{if } x \geq 0 \\
# \alpha x & \text{if } x < 0
# \end{cases}
# $$
# where \( $\alpha$ \) is a small constant (e.g., 0.01).
#
# 6. ELU (Exponential Linear Unit):
# $$
# \operatorname{ELU}(x) =
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where ($\alpha$) is a positive constant.
#
# 7. SELU (Scaled Exponential Linear Unit):
# $$
# \operatorname{SELU}(x) =
# \lambda
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where \( $\lambda$ \) and \( $\alpha$ \) are predefined constants, typically \( $\lambda \approx 1.0507$ \) and \( $\alpha \approx 1.67326$ \).

# %% [markdown]
# ------
# There are several optimizer algorithms for optimizing the neural network over epochs. You should implement some of those mentioned in this section:
#
# ***Stochastic Gradient Descent (SGD)***
#
# SGD is the basic form of gradient descent, where each weight (\( w \)) and bias (\( b \)) parameter is updated in the opposite direction of its gradient.
#
# **Update Rule:**
# $$
# w^{(t+1)} = w^{(t)} - \eta \cdot \nabla_w L(w^{(t)}, b^{(t)})
# $$
# $$
# b^{(t+1)} = b^{(t)} - \eta \cdot \nabla_b L(w^{(t)}, b^{(t)})
# $$
#
# - \( w \): Weight parameters
# - \( b \): Bias parameters
# - \( $\eta$ \): Learning rate
# - \( $\nabla_w L(w, b)$ \): Gradient of the loss with respect to \( w \)
# - \( $\nabla_b L(w, b)$ \): Gradient of the loss with respect to \( b \)
#
# <br><br>
#
# ***Momentum Optimizer***
#
# Momentum optimizer smooths parameter updates by adding a velocity term to accumulate past gradients.
#
# **Update Rule:**
# 1. **Velocity Update for Weights and Biases:**
#    $$
#    v_w^{(t+1)} = \beta \cdot v_w^{(t)} + (1 - \beta) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_b^{(t+1)} = \beta \cdot v_b^{(t)} + (1 - \beta) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#
# 2. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot v_w^{(t+1)}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot v_b^{(t+1)}
#    $$
#
# - \( $v_w$ \): Velocity term for weights
# - \( $v_b$ \): Velocity term for biases
# - \( $\beta$ \): Momentum term, typically set to 0.9
#
# <br><br>
#
# ***Adam Optimizer***
#
# Adam combines momentum and adaptive learning rates, using both first (momentum) and second (RMSprop) moment estimates.
#
# **Update Rule:**
# 1. **Compute biased first and second moment estimates:**
#    $$
#    m_w^{(t+1)} = \beta_1 \cdot m_w^{(t)} + (1 - \beta_1) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    m_b^{(t+1)} = \beta_1 \cdot m_b^{(t)} + (1 - \beta_1) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_w^{(t+1)} = \beta_2 \cdot v_w^{(t)} + (1 - \beta_2) \cdot \left( \nabla_w L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#    $$
#    v_b^{(t+1)} = \beta_2 \cdot v_b^{(t)} + (1 - \beta_2) \cdot \left( \nabla_b L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#
# 2. **Compute bias-corrected estimates:**
#    $$
#    \hat{m}_w^{(t+1)} = \frac{m_w^{(t+1)}}{1 - \beta_1^{t+1}}, \quad \hat{m}_b^{(t+1)} = \frac{m_b^{(t+1)}}{1 - \beta_1^{t+1}}
#    $$
#    $$
#    \hat{v}_w^{(t+1)} = \frac{v_w^{(t+1)}}{1 - \beta_2^{t+1}}, \quad \hat{v}_b^{(t+1)} = \frac{v_b^{(t+1)}}{1 - \beta_2^{t+1}}
#    $$
#
# 3. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot \frac{\hat{m}_w^{(t+1)}}{\sqrt{\hat{v}_w^{(t+1)}} + \epsilon}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot \frac{\hat{m}_b^{(t+1)}}{\sqrt{\hat{v}_b^{(t+1)}} + \epsilon}
#    $$
#
# - \( $m_w$ \), \( $m_b$ \): First moment estimates (mean of gradients) for weights and biases
# - \( $v_w$ \), \( $v_b$ \): Second moment estimates (uncentered variance of gradients) for weights and biases
# - \( $\beta_1$ \): Decay rate for first moment, typically 0.9
# - \( $\beta_2$ \): Decay rate for second moment, typically 0.999
# - \( $\epsilon$ \): Small constant for numerical stability (e.g., \(10^{-8}\))

# %% [markdown]
# # MLP from Scratch

# %%
class MLP():
    def __init__(self, sizes, activation='sigmoid'):
        self.sizes = sizes
        self.num_layers = len(sizes) - 1  # number of layers excluding input
        self.activation_name = activation

        # Choose activation function
        if activation == 'relu':
            self.activation = self.relu
        elif activation == 'sigmoid':
            self.activation = self.sigmoid
        elif activation == 'tanh':
            self.activation = self.tanh
        # -------------------------------- TODO -------------------------------------

        # Do the same for other activation functions
        elif activation == 'leaky_relu':
            self.activation = self.leaky_relu
        elif activation == 'elu':
            self.activation = self.elu
        elif activation == 'selu':
            self.activation = self.selu

        # -------------------------------- TODO -------------------------------------
        else:
            raise ValueError("This activation function is currently not supported!")

        # Save all weights
        self.params = self.initialize()
        # Save all intermediate values, i.e. activations
        self.cache = {}

    # Activation functions remain the same as defined in your original code
    def relu(self, x, derivative=False):
        '''
            Forward path:
            relu(x) = max(0, x)
            In other word,
            relu(x) = 0, if x < 0
                    = x, if x >= 0

            Backward path:
            ∇relu(x) = 0, if x < 0
                     = 1, if x >=0
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x>0, 1, 0)
        else:
            return np.maximum(0,x)
        # -------------------------------- TODO -------------------------------------

    def tanh(self, x, derivative=False):
        '''
            Forward path:
            tanh(x) = (exp(x) - exp(-x)) / (exp(x) + exp(-x))

            Backward path:
            ∇tanh(x) = 1 - tanh(x)^2
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return 1 - np.tanh(x)**2
        else:
            return np.tanh(x)
        # -------------------------------- TODO -------------------------------------

    def sigmoid(self, x, derivative=False):
        '''
            Forward path:
            σ(x) = 1 / 1+exp(-z)

            Backward path:
            ∇σ(x) = exp(-z) / (1+exp(-z))^2
        '''
        # -------------------------------- TODO -------------------------------------
        sig = 1 / (1 + np.exp(-x))
        if derivative:
            return sig * (1 - sig)
        else:
            return sig
        # -------------------------------- TODO -------------------------------------

    def softmax(self, x):
        '''
            softmax(x) = exp(x) / ∑exp(x)
        '''
        # Numerically stable with large exponentials
        # -------------------------------- TODO -------------------------------------
        exp_x = np.exp(x - np.max(x, axis=1, keepdims=True))  # for numerical stability
        return exp_x / np.sum(exp_x, axis=1, keepdims=True)
        # -------------------------------- TODO -------------------------------------


    def leaky_relu(self, x, alpha=0.01, derivative=False):
        '''
            Forward path:
            leaky_relu(x) = x if x >= 0 else αx

            Backward path:
            ∇leaky_relu(x) = 1 if x >= 0 else α
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x > 0, 1, alpha)
        else:
            return np.where(x > 0, x, alpha * x)
        # -------------------------------- TODO -------------------------------------

    def elu(self, x, alpha=1.0, derivative=False):
        '''
            Forward path:
            elu(x) = x if x > 0 else α(exp(x) - 1)

            Backward path:
            ∇elu(x) = 1 if x > 0 else α * exp(x)
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x > 0, 1, alpha * np.exp(x))
        else:
            return np.where(x > 0, x, alpha * (np.exp(x) - 1))
        # -------------------------------- TODO -------------------------------------


    def selu(self, x, lambda_=1.0507, alpha=1.67326, derivative=False):
        '''
            Forward path:
            selu(x) = λ * (x if x > 0 else α * (exp(x) - 1))

            Backward path:
            ∇selu(x) = λ * (1 if x > 0 else α * exp(x))
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return lambda_ * np.where(x > 0, 1, alpha * np.exp(x))
        else:
            return lambda_ * np.where(x > 0, x, alpha * (np.exp(x) - 1))
        # -------------------------------- TODO -------------------------------------


    def initialize(self):
        params = {}
        for i in range(1, self.num_layers + 1):
            input_layer = self.sizes[i - 1]
            output_layer = self.sizes[i]
            params[f"W{i}"] = np.random.randn(output_layer, input_layer) * np.sqrt(1. / input_layer)
            params[f"b{i}"] = np.zeros((output_layer, 1))
        return params

    def feed_forward(self, x):
        self.cache["A0"] = x.T
        # -------------------------------- TODO -------------------------------------
        # Perform feedforward pass through each hidden layer, applying weights, biases, and activation function
        for i in range(1, self.num_layers + 1):
            W = self.params[f"W{i}"]
            b = self.params[f"b{i}"]
            Z = np.dot(W, self.cache[f"A{i-1}"]) + b
            if i == self.num_layers:
                A = self.softmax(Z.T).T  # Softmax for the output layer
            else:
                A = self.activation(Z.T).T
            self.cache[f"Z{i}"] = Z
            self.cache[f"A{i}"] = A

        # -------------------------------- TODO -------------------------------------

        return self.cache[f"A{self.num_layers}"]

    def back_propagate(self, y, output):
        grads = {}

        # -------------------------------- TODO -------------------------------------
        # Backpropagate gradients through Output layer and each hidden layers
        current_batch_size = y.shape[0]
        y = y.T
        m = y.shape[1]
        output = output

        dA = -(y - output)  # Initial gradient of the loss w.r.t output
        for i in reversed(range(1, self.num_layers + 1)):
            Z = self.cache[f"Z{i}"]
            A_prev = self.cache[f"A{i-1}"]
            W = self.params[f"W{i}"]

            if i == self.num_layers:
                dZ = dA
            else:
                dZ = dA * self.activation(Z.T, derivative=True).T

            grads[f"dW{i}"] = np.dot(dZ, A_prev.T) / m
            grads[f"db{i}"] = np.sum(dZ, axis=1, keepdims=True) / m
            dA = np.dot(W.T, dZ)

        # -------------------------------- TODO -------------------------------------

        self.grads = grads
        return self.grads


    def cross_entropy_loss(self, y, output):
        '''
            L(y, ŷ) = −∑ylog(ŷ).
        '''
        # -------------------------------- TODO -------------------------------------
        # Compute cross-entropy loss as the negative average log-likelihood of the correct labels
        m = y.shape[0]
        loss = -np.sum(y.T * np.log(output + 1e-8)) / m

        # -------------------------------- TODO -------------------------------------
        return loss

    def initialize_momemtum_optimizer(self):
        momemtum_opt = {}
        for i in range(1, self.num_layers + 1):
            # -------------------------------- TODO -------------------------------------
            # Initialize zero matrices for momentum updates of weights and biases in each layer
            momemtum_opt[f"vW{i}"] = np.zeros_like(self.params[f"W{i}"])
            momemtum_opt[f"vb{i}"] = np.zeros_like(self.params[f"b{i}"])
            # -------------------------------- TODO -------------------------------------
        return momemtum_opt

    def initialize_adam_optimizer(self):
        adam_opt = {}
        for i in range(1, self.num_layers + 1):
            # -------------------------------- TODO -------------------------------------
            # Initialize zero matrices for first and second moment estimates of weights and biases in each layer
            adam_opt[f"mW{i}"] = np.zeros_like(self.params[f"W{i}"])
            adam_opt[f"mb{i}"] = np.zeros_like(self.params[f"b{i}"])
            adam_opt[f"vW{i}"] = np.zeros_like(self.params[f"W{i}"])
            adam_opt[f"vb{i}"] = np.zeros_like(self.params[f"b{i}"])
            # -------------------------------- TODO -------------------------------------
        return adam_opt

    def optimize(self, l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):

        if self.optimizer == "sgd":
            for key in self.params:
              if "W" in key or "b" in key:  # Update only weights and biases
                # -------------------------------- TODO -------------------------------------
                # Update rule for SGD
                self.params[key] -= l_rate * self.grads[f"d{key}"]
                # -------------------------------- TODO -------------------------------------
        elif self.optimizer == "momentum":
            for key in self.params:
              if "W" in key or "b" in key:  # Update only weights and biases
                # -------------------------------- TODO -------------------------------------
                # Update rule for Momentum
                self.momemtum_opt[f"v{key}"] = beta * self.momemtum_opt[f"v{key}"] + (1 - beta) * self.grads[f"d{key}"]
                self.params[key] -= l_rate * self.momemtum_opt[f"v{key}"]
                # -------------------------------- TODO -------------------------------------
        elif self.optimizer == "adam":
            for key in self.params:
              if "W" in key or "b" in key:  # Update only weights and biases
                # -------------------------------- TODO -------------------------------------
                # Update rule for Adam
                self.adam_opt[f"m{key}"] = beta1 * self.adam_opt[f"m{key}"] + (1 - beta1) * self.grads[f"d{key}"]
                self.adam_opt[f"v{key}"] = beta2 * self.adam_opt[f"v{key}"] + (1 - beta2) * (self.grads[f"d{key}"] ** 2)

                m_corr = self.adam_opt[f"m{key}"] / (1 - beta1 ** t)
                v_corr = self.adam_opt[f"v{key}"] / (1 - beta2 ** t)

                self.params[key] -= l_rate * m_corr / (np.sqrt(v_corr) + epsilon)
                # -------------------------------- TODO -------------------------------------
        else:
            raise ValueError("This optimizer is currently not supported!")

    # Accuracy, loss, and training methods remain the same as defined in your original code


    def accuracy(self, y, output):
        # -------------------------------- TODO -------------------------------------
        # Calculate accuracy by comparing the pred and truth matrices
        pred = np.argmax(output.T, axis=1)
        truth = np.argmax(y, axis=1)
        return np.mean(pred == truth)

        # -------------------------------- TODO -------------------------------------

    def train(self, x_train, y_train, x_val, y_val, epochs=10,
              batch_size=64, optimizer='momentum', l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):
        # Hyperparameters
        self.epochs = epochs
        self.batch_size = batch_size
        num_batches = -(-x_train.shape[0] // self.batch_size)

        # Initialize optimizer
        self.optimizer = optimizer
        if self.optimizer == 'momentum':
          self.momemtum_opt = self.initialize_momemtum_optimizer()
        elif self.optimizer == 'adam':
          self.adam_opt = self.initialize_adam_optimizer()

        start_time = time.time()

        # Train
        for i in range(self.epochs):
            # Shuffle
            permutation = np.random.permutation(x_train.shape[0])
            x_train_shuffled = x_train[permutation]
            y_train_shuffled = y_train[permutation]

            for j in range(num_batches):
                # Batch
                begin = j * self.batch_size
                end = min(begin + self.batch_size, x_train.shape[0]-1)
                x = x_train_shuffled[begin:end]
                y = y_train_shuffled[begin:end]

                # Forward
                output = self.feed_forward(x)
                # Backprop
                grad = self.back_propagate(y, output)
                # Optimize
                self.optimize(l_rate=l_rate, beta=beta, beta1=beta1, beta2=beta2, epsilon=epsilon, t=t)

            # Evaluate performance
            # Training data
            output = self.feed_forward(x_train)
            train_acc = self.accuracy(y_train, output)
            train_loss = self.cross_entropy_loss(y_train, output)
            # Test data
            output = self.feed_forward(x_val)
            val_acc = self.accuracy(y_val, output)
            val_loss = self.cross_entropy_loss(y_val, output)
            print(f'Epoch {i+1}: {time.time()-start_time:.2f}s, train acc={train_acc:.2f}, train loss={train_loss:.2f}, '
                      f'validation acc={val_acc:.2f}, validation loss={val_loss:.2f}')

    def evaluate(self, x_test, y_test):
        # Test data
        output = self.feed_forward(x_test)
        test_acc = self.accuracy(y_test, output)
        test_loss = self.cross_entropy_loss(y_test, output)
        print(f'\nTest acc={test_acc:.2f}, Test loss={test_loss:.2f}')

# %% [markdown]
# Please run experiments with different combinations of optimizers (SGD, Momentum, and Adam) and activation functions (ReLU, Sigmoid, Tanh, Leaky ReLU, SELU, and ELU) over 20 epochs each. Consider networks with three layers (without input layer) whose number of neurons is 128, 64 and 10 respectively. Also consider two learning rates 0.01 and 0.001.
#
#
# After testing all combinations, report which combination of optimizer, activation function, and learning rate performs best.

# %%
# Determine input size dynamically
input_size = x_train.shape[1]
# Hyperparameters to test
optimizers = ['sgd', 'momentum', 'adam']
activations = ['relu', 'sigmoid', 'tanh', 'leaky_relu', 'selu', 'elu']
learning_rates = [0.01, 0.001]

# Store results
results = []

# Test all combinations
for optimizer in optimizers:
    for activation in activations:
        for l_rate in learning_rates:
            print(f"Testing optimizer={optimizer}, activation={activation}, learning_rate={l_rate}")
            try:
                # Initialize MLP with the current activation
                mlp = MLP(sizes=[input_size, 128, 64, 10], activation=activation)

                # Train the MLP
                mlp.train(
                    x_train=x_train,
                    y_train=y_train,
                    x_val=x_test,
                    y_val=y_test,
                    epochs=20,
                    optimizer=optimizer,
                    l_rate=l_rate,
                )

                # Evaluate on validation set
                output = mlp.feed_forward(x_test)
                val_acc = mlp.accuracy(y_test, output)

                # Append results
                results.append({
                    "optimizer": optimizer,
                    "activation": activation,
                    "learning_rate": l_rate,
                    "validation_accuracy": val_acc
                })
            except Exception as e:
                print(f"Error with combination optimizer={optimizer}, activation={activation}, learning_rate={l_rate}: {e}")
# Out:
# Testing optimizer=sgd, activation=relu, learning_rate=0.01
# Epoch 1: 3.83s, train acc=0.88, train loss=0.46, validation acc=0.87, validation loss=0.49
# Epoch 2: 7.66s, train acc=0.91, train loss=0.34, validation acc=0.89, validation loss=0.38
# Epoch 3: 14.37s, train acc=0.92, train loss=0.29, validation acc=0.90, validation loss=0.34
# Epoch 4: 18.01s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.31
# Epoch 5: 21.69s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.29
# Epoch 6: 28.12s, train acc=0.94, train loss=0.23, validation acc=0.92, validation loss=0.27
# Epoch 7: 31.77s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.26
# Epoch 8: 35.48s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.24
# Epoch 9: 40.11s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.23
# Epoch 10: 45.33s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 11: 49.02s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 12: 52.66s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Epoch 13: 59.30s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.19
# Epoch 14: 63.03s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.18
# Epoch 15: 66.67s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.18
# Epoch 16: 73.38s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.17
# Epoch 17: 77.08s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 18: 80.78s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.16
# Epoch 19: 88.50s, train acc=0.97, train loss=0.11, validation acc=0.95, validation loss=0.16
# Epoch 20: 92.21s, train acc=0.97, train loss=0.11, validation acc=0.95, validation loss=0.16
# Testing optimizer=sgd, activation=relu, learning_rate=0.001
# Epoch 1: 3.80s, train acc=0.53, train loss=2.08, validation acc=0.53, validation loss=2.08
# Epoch 2: 10.11s, train acc=0.69, train loss=1.74, validation acc=0.68, validation loss=1.74
# Epoch 3: 13.80s, train acc=0.75, train loss=1.33, validation acc=0.74, validation loss=1.34
# Epoch 4: 17.43s, train acc=0.79, train loss=1.01, validation acc=0.78, validation loss=1.02
# Epoch 5: 22.87s, train acc=0.82, train loss=0.80, validation acc=0.81, validation loss=0.83
# Epoch 6: 27.28s, train acc=0.84, train loss=0.68, validation acc=0.83, validation loss=0.70
# Epoch 7: 30.86s, train acc=0.85, train loss=0.60, validation acc=0.84, validation loss=0.63
# Epoch 8: 34.45s, train acc=0.86, train loss=0.54, validation acc=0.85, validation loss=0.57
# Epoch 9: 40.63s, train acc=0.87, train loss=0.50, validation acc=0.86, validation loss=0.53
# Epoch 10: 44.24s, train acc=0.88, train loss=0.47, validation acc=0.87, validation loss=0.50
# Epoch 11: 47.86s, train acc=0.88, train loss=0.44, validation acc=0.87, validation loss=0.47
# Epoch 12: 54.27s, train acc=0.89, train loss=0.42, validation acc=0.88, validation loss=0.46
# Epoch 13: 57.82s, train acc=0.89, train loss=0.41, validation acc=0.88, validation loss=0.44
# Epoch 14: 61.49s, train acc=0.89, train loss=0.39, validation acc=0.88, validation loss=0.43
# Epoch 15: 66.35s, train acc=0.90, train loss=0.38, validation acc=0.89, validation loss=0.41
# Epoch 16: 71.44s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.41
# Epoch 17: 77.66s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.40
# Epoch 18: 83.97s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 19: 87.54s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.38
# Epoch 20: 91.14s, train acc=0.90, train loss=0.34, validation acc=0.89, validation loss=0.38
# Testing optimizer=sgd, activation=sigmoid, learning_rate=0.01
# Epoch 1: 5.70s, train acc=0.16, train loss=2.25, validation acc=0.16, validation loss=2.26
# Epoch 2: 10.90s, train acc=0.36, train loss=2.17, validation acc=0.36, validation loss=2.17
# Epoch 3: 15.14s, train acc=0.54, train loss=2.00, validation acc=0.53, validation loss=2.00
# Epoch 4: 21.00s, train acc=0.65, train loss=1.67, validation acc=0.63, validation loss=1.68
# Epoch 5: 26.10s, train acc=0.70, train loss=1.33, validation acc=0.69, validation loss=1.34
# Epoch 6: 30.32s, train acc=0.73, train loss=1.10, validation acc=0.73, validation loss=1.12
# Epoch 7: 36.23s, train acc=0.76, train loss=0.95, validation acc=0.76, validation loss=0.97
# Epoch 8: 41.18s, train acc=0.78, train loss=0.84, validation acc=0.78, validation loss=0.86
# Epoch 9: 45.48s, train acc=0.81, train loss=0.75, validation acc=0.80, validation loss=0.77
# Epoch 10: 51.91s, train acc=0.82, train loss=0.68, validation acc=0.82, validation loss=0.70
# Epoch 11: 56.55s, train acc=0.84, train loss=0.62, validation acc=0.83, validation loss=0.65
# Epoch 12: 60.90s, train acc=0.85, train loss=0.57, validation acc=0.84, validation loss=0.60
# Epoch 13: 67.92s, train acc=0.86, train loss=0.54, validation acc=0.85, validation loss=0.56
# Epoch 14: 72.18s, train acc=0.87, train loss=0.51, validation acc=0.86, validation loss=0.53
# Epoch 15: 76.46s, train acc=0.87, train loss=0.48, validation acc=0.87, validation loss=0.51
# Epoch 16: 83.45s, train acc=0.88, train loss=0.46, validation acc=0.87, validation loss=0.49
# Epoch 17: 87.70s, train acc=0.88, train loss=0.44, validation acc=0.88, validation loss=0.47
# Epoch 18: 92.00s, train acc=0.89, train loss=0.42, validation acc=0.88, validation loss=0.45
# Epoch 19: 99.36s, train acc=0.89, train loss=0.41, validation acc=0.88, validation loss=0.44
# Epoch 20: 103.69s, train acc=0.89, train loss=0.40, validation acc=0.88, validation loss=0.43
# Testing optimizer=sgd, activation=sigmoid, learning_rate=0.001
# Epoch 1: 4.57s, train acc=0.11, train loss=2.30, validation acc=0.11, validation loss=2.30
# Epoch 2: 11.10s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 3: 15.43s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 4: 20.94s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 5: 26.68s, train acc=0.12, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 6: 31.04s, train acc=0.12, train loss=2.28, validation acc=0.12, validation loss=2.28
# Epoch 7: 37.41s, train acc=0.13, train loss=2.27, validation acc=0.13, validation loss=2.27
# Epoch 8: 42.39s, train acc=0.15, train loss=2.27, validation acc=0.15, validation loss=2.27
# Epoch 9: 46.75s, train acc=0.16, train loss=2.26, validation acc=0.16, validation loss=2.26
# Epoch 10: 53.71s, train acc=0.19, train loss=2.26, validation acc=0.18, validation loss=2.26
# Epoch 11: 58.04s, train acc=0.23, train loss=2.25, validation acc=0.22, validation loss=2.25
# Epoch 12: 62.34s, train acc=0.26, train loss=2.25, validation acc=0.26, validation loss=2.25
# Epoch 13: 69.52s, train acc=0.28, train loss=2.24, validation acc=0.27, validation loss=2.24
# Epoch 14: 73.92s, train acc=0.29, train loss=2.23, validation acc=0.28, validation loss=2.23
# Epoch 15: 78.39s, train acc=0.33, train loss=2.23, validation acc=0.32, validation loss=2.23
# Epoch 16: 85.72s, train acc=0.37, train loss=2.22, validation acc=0.36, validation loss=2.22
# Epoch 17: 90.04s, train acc=0.36, train loss=2.21, validation acc=0.36, validation loss=2.21
# Epoch 18: 94.87s, train acc=0.42, train loss=2.20, validation acc=0.41, validation loss=2.20
# Epoch 19: 101.22s, train acc=0.42, train loss=2.19, validation acc=0.42, validation loss=2.19
# Epoch 20: 106.70s, train acc=0.43, train loss=2.18, validation acc=0.43, validation loss=2.18
# Testing optimizer=sgd, activation=tanh, learning_rate=0.01
# Epoch 1: 8.96s, train acc=0.88, train loss=0.50, validation acc=0.86, validation loss=0.53
# Epoch 2: 15.14s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.41
# Epoch 3: 24.33s, train acc=0.91, train loss=0.33, validation acc=0.90, validation loss=0.36
# Epoch 4: 30.51s, train acc=0.92, train loss=0.30, validation acc=0.91, validation loss=0.34
# Epoch 5: 39.52s, train acc=0.92, train loss=0.28, validation acc=0.91, validation loss=0.32
# Epoch 6: 45.86s, train acc=0.93, train loss=0.26, validation acc=0.91, validation loss=0.30
# Epoch 7: 54.77s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.29
# Epoch 8: 60.97s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.28
# Epoch 9: 69.96s, train acc=0.94, train loss=0.22, validation acc=0.92, validation loss=0.27
# Epoch 10: 76.23s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.26
# Epoch 11: 84.88s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.25
# Epoch 12: 91.34s, train acc=0.94, train loss=0.19, validation acc=0.93, validation loss=0.24
# Epoch 13: 99.89s, train acc=0.95, train loss=0.19, validation acc=0.93, validation loss=0.24
# Epoch 14: 106.28s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.23
# Epoch 15: 114.88s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 16: 124.57s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 17: 131.62s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 18: 138.60s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Epoch 19: 146.13s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Epoch 20: 153.50s, train acc=0.96, train loss=0.14, validation acc=0.94, validation loss=0.19
# Testing optimizer=sgd, activation=tanh, learning_rate=0.001
# Epoch 1: 7.12s, train acc=0.66, train loss=1.75, validation acc=0.65, validation loss=1.76
# Epoch 2: 13.86s, train acc=0.75, train loss=1.32, validation acc=0.74, validation loss=1.33
# Epoch 3: 21.39s, train acc=0.79, train loss=1.05, validation acc=0.77, validation loss=1.07
# Epoch 4: 27.98s, train acc=0.81, train loss=0.88, validation acc=0.80, validation loss=0.90
# Epoch 5: 35.90s, train acc=0.83, train loss=0.76, validation acc=0.82, validation loss=0.79
# Epoch 6: 42.48s, train acc=0.85, train loss=0.69, validation acc=0.83, validation loss=0.71
# Epoch 7: 50.50s, train acc=0.86, train loss=0.63, validation acc=0.85, validation loss=0.65
# Epoch 8: 57.01s, train acc=0.86, train loss=0.58, validation acc=0.86, validation loss=0.61
# Epoch 9: 65.27s, train acc=0.87, train loss=0.54, validation acc=0.86, validation loss=0.57
# Epoch 10: 71.72s, train acc=0.88, train loss=0.51, validation acc=0.87, validation loss=0.54
# Epoch 11: 79.89s, train acc=0.88, train loss=0.49, validation acc=0.87, validation loss=0.52
# Epoch 12: 86.24s, train acc=0.88, train loss=0.47, validation acc=0.88, validation loss=0.50
# Epoch 13: 94.70s, train acc=0.89, train loss=0.45, validation acc=0.88, validation loss=0.48
# Epoch 14: 100.99s, train acc=0.89, train loss=0.44, validation acc=0.88, validation loss=0.47
# Epoch 15: 109.69s, train acc=0.89, train loss=0.42, validation acc=0.88, validation loss=0.46
# Epoch 16: 115.82s, train acc=0.89, train loss=0.41, validation acc=0.88, validation loss=0.44
# Epoch 17: 124.48s, train acc=0.90, train loss=0.40, validation acc=0.89, validation loss=0.43
# Epoch 18: 130.61s, train acc=0.90, train loss=0.39, validation acc=0.89, validation loss=0.43
# Epoch 19: 139.37s, train acc=0.90, train loss=0.38, validation acc=0.89, validation loss=0.42
# Epoch 20: 145.44s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.41
# Testing optimizer=sgd, activation=leaky_relu, learning_rate=0.01
# Epoch 1: 6.50s, train acc=0.88, train loss=0.47, validation acc=0.87, validation loss=0.50
# Epoch 2: 10.10s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 3: 13.78s, train acc=0.91, train loss=0.30, validation acc=0.90, validation loss=0.34
# Epoch 4: 20.09s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.32
# Epoch 5: 23.81s, train acc=0.93, train loss=0.25, validation acc=0.91, validation loss=0.30
# Epoch 6: 27.54s, train acc=0.93, train loss=0.23, validation acc=0.92, validation loss=0.28
# Epoch 7: 33.29s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.26
# Epoch 8: 37.59s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.25
# Epoch 9: 41.31s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.24
# Epoch 10: 45.30s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.23
# Epoch 11: 51.22s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 12: 54.98s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 13: 58.68s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Epoch 14: 65.38s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Epoch 15: 69.10s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.19
# Epoch 16: 72.83s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.18
# Epoch 17: 78.87s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.18
# Epoch 18: 82.61s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 19: 86.32s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 20: 91.06s, train acc=0.97, train loss=0.11, validation acc=0.95, validation loss=0.16
# Testing optimizer=sgd, activation=leaky_relu, learning_rate=0.001
# Epoch 1: 5.29s, train acc=0.52, train loss=2.07, validation acc=0.51, validation loss=2.07
# Epoch 2: 9.01s, train acc=0.67, train loss=1.73, validation acc=0.66, validation loss=1.74
# Epoch 3: 12.73s, train acc=0.73, train loss=1.33, validation acc=0.72, validation loss=1.34
# Epoch 4: 18.80s, train acc=0.78, train loss=1.01, validation acc=0.77, validation loss=1.03
# Epoch 5: 22.43s, train acc=0.81, train loss=0.82, validation acc=0.80, validation loss=0.84
# Epoch 6: 26.08s, train acc=0.84, train loss=0.69, validation acc=0.83, validation loss=0.72
# Epoch 7: 32.67s, train acc=0.85, train loss=0.61, validation acc=0.84, validation loss=0.64
# Epoch 8: 36.31s, train acc=0.86, train loss=0.55, validation acc=0.85, validation loss=0.58
# Epoch 9: 40.01s, train acc=0.87, train loss=0.51, validation acc=0.86, validation loss=0.54
# Epoch 10: 45.12s, train acc=0.88, train loss=0.47, validation acc=0.87, validation loss=0.51
# Epoch 11: 50.05s, train acc=0.88, train loss=0.45, validation acc=0.87, validation loss=0.48
# Epoch 12: 53.78s, train acc=0.89, train loss=0.43, validation acc=0.88, validation loss=0.46
# Epoch 13: 57.38s, train acc=0.89, train loss=0.41, validation acc=0.88, validation loss=0.44
# Epoch 14: 63.93s, train acc=0.89, train loss=0.40, validation acc=0.88, validation loss=0.43
# Epoch 15: 67.58s, train acc=0.90, train loss=0.38, validation acc=0.89, validation loss=0.42
# Epoch 16: 71.25s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.41
# Epoch 17: 77.77s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.40
# Epoch 18: 83.57s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.39
# Epoch 19: 87.27s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 20: 93.82s, train acc=0.90, train loss=0.34, validation acc=0.89, validation loss=0.38
# Testing optimizer=sgd, activation=selu, learning_rate=0.01
# Epoch 1: 4.44s, train acc=0.89, train loss=0.38, validation acc=0.88, validation loss=0.41
# Epoch 2: 9.07s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.36
# Epoch 3: 16.09s, train acc=0.92, train loss=0.29, validation acc=0.90, validation loss=0.33
# Epoch 4: 20.61s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.32
# Epoch 5: 26.31s, train acc=0.93, train loss=0.26, validation acc=0.91, validation loss=0.31
# Epoch 6: 31.60s, train acc=0.93, train loss=0.24, validation acc=0.91, validation loss=0.30
# Epoch 7: 36.24s, train acc=0.93, train loss=0.23, validation acc=0.92, validation loss=0.29
# Epoch 8: 43.16s, train acc=0.94, train loss=0.22, validation acc=0.92, validation loss=0.28
# Epoch 9: 47.60s, train acc=0.94, train loss=0.21, validation acc=0.92, validation loss=0.27
# Epoch 10: 52.06s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.26
# Epoch 11: 59.24s, train acc=0.94, train loss=0.19, validation acc=0.93, validation loss=0.25
# Epoch 12: 63.65s, train acc=0.95, train loss=0.18, validation acc=0.93, validation loss=0.24
# Epoch 13: 68.92s, train acc=0.95, train loss=0.18, validation acc=0.93, validation loss=0.23
# Epoch 14: 75.00s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.23
# Epoch 15: 79.51s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.22
# Epoch 16: 86.05s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 17: 90.92s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.21
# Epoch 18: 95.39s, train acc=0.96, train loss=0.14, validation acc=0.94, validation loss=0.20
# Epoch 19: 102.75s, train acc=0.96, train loss=0.14, validation acc=0.94, validation loss=0.20
# Epoch 20: 107.24s, train acc=0.96, train loss=0.13, validation acc=0.94, validation loss=0.19
# Testing optimizer=sgd, activation=selu, learning_rate=0.001
# Epoch 1: 4.59s, train acc=0.77, train loss=1.08, validation acc=0.77, validation loss=1.09
# Epoch 2: 11.93s, train acc=0.84, train loss=0.74, validation acc=0.83, validation loss=0.76
# Epoch 3: 16.39s, train acc=0.86, train loss=0.60, validation acc=0.85, validation loss=0.62
# Epoch 4: 21.90s, train acc=0.87, train loss=0.52, validation acc=0.86, validation loss=0.55
# Epoch 5: 27.69s, train acc=0.88, train loss=0.47, validation acc=0.87, validation loss=0.50
# Epoch 6: 32.19s, train acc=0.88, train loss=0.44, validation acc=0.88, validation loss=0.47
# Epoch 7: 39.39s, train acc=0.89, train loss=0.42, validation acc=0.88, validation loss=0.45
# Epoch 8: 43.95s, train acc=0.89, train loss=0.40, validation acc=0.88, validation loss=0.43
# Epoch 9: 48.50s, train acc=0.90, train loss=0.38, validation acc=0.89, validation loss=0.42
# Epoch 10: 55.83s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.41
# Epoch 11: 60.27s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.40
# Epoch 12: 64.83s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 13: 71.82s, train acc=0.90, train loss=0.34, validation acc=0.89, validation loss=0.38
# Epoch 14: 76.30s, train acc=0.90, train loss=0.34, validation acc=0.89, validation loss=0.38
# Epoch 15: 82.04s, train acc=0.91, train loss=0.33, validation acc=0.90, validation loss=0.37
# Epoch 16: 87.90s, train acc=0.91, train loss=0.33, validation acc=0.90, validation loss=0.37
# Epoch 17: 92.40s, train acc=0.91, train loss=0.32, validation acc=0.90, validation loss=0.36
# Epoch 18: 98.97s, train acc=0.91, train loss=0.32, validation acc=0.90, validation loss=0.36
# Epoch 19: 103.80s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.35
# Epoch 20: 108.26s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.35
# Testing optimizer=sgd, activation=elu, learning_rate=0.01
# Epoch 1: 7.21s, train acc=0.88, train loss=0.44, validation acc=0.87, validation loss=0.47
# Epoch 2: 11.62s, train acc=0.90, train loss=0.34, validation acc=0.89, validation loss=0.38
# Epoch 3: 16.02s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.35
# Epoch 4: 23.11s, train acc=0.92, train loss=0.29, validation acc=0.91, validation loss=0.33
# Epoch 5: 27.52s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.32
# Epoch 6: 32.81s, train acc=0.92, train loss=0.26, validation acc=0.91, validation loss=0.31
# Epoch 7: 38.91s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.30
# Epoch 8: 43.36s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.29
# Epoch 9: 49.72s, train acc=0.93, train loss=0.23, validation acc=0.92, validation loss=0.28
# Epoch 10: 54.77s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.27
# Epoch 11: 59.20s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.26
# Epoch 12: 66.11s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.25
# Epoch 13: 70.53s, train acc=0.94, train loss=0.19, validation acc=0.93, validation loss=0.24
# Epoch 14: 75.01s, train acc=0.95, train loss=0.19, validation acc=0.93, validation loss=0.24
# Epoch 15: 82.38s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.23
# Epoch 16: 86.98s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 17: 92.84s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 18: 98.58s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 19: 103.21s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Epoch 20: 110.32s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Testing optimizer=sgd, activation=elu, learning_rate=0.001
# Epoch 1: 4.65s, train acc=0.72, train loss=1.62, validation acc=0.71, validation loss=1.63
# Epoch 2: 9.28s, train acc=0.77, train loss=1.16, validation acc=0.77, validation loss=1.17
# Epoch 3: 18.33s, train acc=0.81, train loss=0.89, validation acc=0.80, validation loss=0.91
# Epoch 4: 22.76s, train acc=0.84, train loss=0.73, validation acc=0.83, validation loss=0.76
# Epoch 5: 27.56s, train acc=0.85, train loss=0.64, validation acc=0.85, validation loss=0.66
# Epoch 6: 34.09s, train acc=0.86, train loss=0.57, validation acc=0.85, validation loss=0.60
# Epoch 7: 38.52s, train acc=0.87, train loss=0.52, validation acc=0.86, validation loss=0.55
# Epoch 8: 44.40s, train acc=0.87, train loss=0.49, validation acc=0.87, validation loss=0.52
# Epoch 9: 49.54s, train acc=0.88, train loss=0.46, validation acc=0.87, validation loss=0.49
# Epoch 10: 54.03s, train acc=0.88, train loss=0.44, validation acc=0.87, validation loss=0.47
# Epoch 11: 61.05s, train acc=0.89, train loss=0.42, validation acc=0.88, validation loss=0.45
# Epoch 12: 65.60s, train acc=0.89, train loss=0.41, validation acc=0.88, validation loss=0.44
# Epoch 13: 70.10s, train acc=0.89, train loss=0.39, validation acc=0.88, validation loss=0.43
# Epoch 14: 77.37s, train acc=0.89, train loss=0.38, validation acc=0.89, validation loss=0.42
# Epoch 15: 81.74s, train acc=0.90, train loss=0.38, validation acc=0.89, validation loss=0.41
# Epoch 16: 86.40s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.40
# Epoch 17: 92.82s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.40
# Epoch 18: 97.28s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 19: 103.13s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.38
# Epoch 20: 108.49s, train acc=0.90, train loss=0.34, validation acc=0.89, validation loss=0.38
# Testing optimizer=momentum, activation=relu, learning_rate=0.01
# Epoch 1: 4.06s, train acc=0.88, train loss=0.46, validation acc=0.86, validation loss=0.49
# Epoch 2: 9.95s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 3: 14.65s, train acc=0.92, train loss=0.30, validation acc=0.90, validation loss=0.34
# Epoch 4: 18.67s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.31
# Epoch 5: 24.40s, train acc=0.93, train loss=0.25, validation acc=0.91, validation loss=0.29
# Epoch 6: 29.14s, train acc=0.93, train loss=0.23, validation acc=0.92, validation loss=0.27
# Epoch 7: 33.16s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.26
# Epoch 8: 38.62s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.24
# Epoch 9: 43.68s, train acc=0.95, train loss=0.18, validation acc=0.93, validation loss=0.23
# Epoch 10: 47.84s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 11: 53.39s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 12: 58.65s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Epoch 13: 62.80s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.19
# Epoch 14: 68.32s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.19
# Epoch 15: 73.62s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.18
# Epoch 16: 77.75s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.18
# Epoch 17: 83.56s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 18: 88.59s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 19: 92.74s, train acc=0.97, train loss=0.11, validation acc=0.95, validation loss=0.16
# Epoch 20: 98.32s, train acc=0.97, train loss=0.11, validation acc=0.95, validation loss=0.16
# Testing optimizer=momentum, activation=relu, learning_rate=0.001
# Epoch 1: 5.07s, train acc=0.43, train loss=2.02, validation acc=0.42, validation loss=2.02
# Epoch 2: 9.16s, train acc=0.63, train loss=1.64, validation acc=0.61, validation loss=1.65
# Epoch 3: 14.37s, train acc=0.74, train loss=1.25, validation acc=0.73, validation loss=1.26
# Epoch 4: 19.89s, train acc=0.79, train loss=0.96, validation acc=0.78, validation loss=0.97
# Epoch 5: 23.95s, train acc=0.82, train loss=0.78, validation acc=0.81, validation loss=0.80
# Epoch 6: 28.88s, train acc=0.84, train loss=0.66, validation acc=0.84, validation loss=0.69
# Epoch 7: 34.62s, train acc=0.85, train loss=0.59, validation acc=0.85, validation loss=0.61
# Epoch 8: 38.71s, train acc=0.86, train loss=0.53, validation acc=0.86, validation loss=0.56
# Epoch 9: 43.37s, train acc=0.87, train loss=0.50, validation acc=0.86, validation loss=0.52
# Epoch 10: 49.48s, train acc=0.88, train loss=0.47, validation acc=0.87, validation loss=0.49
# Epoch 11: 53.58s, train acc=0.88, train loss=0.44, validation acc=0.88, validation loss=0.47
# Epoch 12: 58.10s, train acc=0.89, train loss=0.42, validation acc=0.88, validation loss=0.45
# Epoch 13: 64.18s, train acc=0.89, train loss=0.41, validation acc=0.88, validation loss=0.44
# Epoch 14: 68.29s, train acc=0.89, train loss=0.39, validation acc=0.89, validation loss=0.43
# Epoch 15: 72.61s, train acc=0.90, train loss=0.38, validation acc=0.89, validation loss=0.42
# Epoch 16: 79.10s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.41
# Epoch 17: 83.16s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.40
# Epoch 18: 87.49s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 19: 94.00s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.38
# Epoch 20: 98.16s, train acc=0.91, train loss=0.34, validation acc=0.90, validation loss=0.38
# Testing optimizer=momentum, activation=sigmoid, learning_rate=0.01
# Epoch 1: 5.33s, train acc=0.15, train loss=2.26, validation acc=0.15, validation loss=2.26
# Epoch 2: 11.89s, train acc=0.39, train loss=2.18, validation acc=0.39, validation loss=2.18
# Epoch 3: 16.52s, train acc=0.44, train loss=2.01, validation acc=0.43, validation loss=2.01
# Epoch 4: 23.78s, train acc=0.54, train loss=1.73, validation acc=0.54, validation loss=1.73
# Epoch 5: 28.53s, train acc=0.62, train loss=1.44, validation acc=0.62, validation loss=1.45
# Epoch 6: 33.23s, train acc=0.69, train loss=1.22, validation acc=0.68, validation loss=1.23
# Epoch 7: 40.64s, train acc=0.73, train loss=1.04, validation acc=0.73, validation loss=1.05
# Epoch 8: 45.37s, train acc=0.77, train loss=0.90, validation acc=0.76, validation loss=0.91
# Epoch 9: 51.53s, train acc=0.80, train loss=0.79, validation acc=0.79, validation loss=0.81
# Epoch 10: 60.15s, train acc=0.82, train loss=0.71, validation acc=0.81, validation loss=0.73
# Epoch 11: 66.02s, train acc=0.83, train loss=0.65, validation acc=0.82, validation loss=0.67
# Epoch 12: 71.95s, train acc=0.84, train loss=0.60, validation acc=0.84, validation loss=0.62
# Epoch 13: 76.60s, train acc=0.85, train loss=0.56, validation acc=0.85, validation loss=0.58
# Epoch 14: 84.08s, train acc=0.86, train loss=0.52, validation acc=0.86, validation loss=0.55
# Epoch 15: 88.75s, train acc=0.87, train loss=0.49, validation acc=0.86, validation loss=0.52
# Epoch 16: 93.43s, train acc=0.87, train loss=0.47, validation acc=0.87, validation loss=0.50
# Epoch 17: 101.02s, train acc=0.88, train loss=0.45, validation acc=0.87, validation loss=0.48
# Epoch 18: 105.78s, train acc=0.88, train loss=0.43, validation acc=0.88, validation loss=0.46
# Epoch 19: 112.18s, train acc=0.89, train loss=0.42, validation acc=0.88, validation loss=0.45
# Epoch 20: 117.41s, train acc=0.89, train loss=0.40, validation acc=0.88, validation loss=0.43
# Testing optimizer=momentum, activation=sigmoid, learning_rate=0.001
# Epoch 1: 4.69s, train acc=0.11, train loss=2.30, validation acc=0.11, validation loss=2.30
# Epoch 2: 12.39s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 3: 17.01s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 4: 22.08s, train acc=0.12, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 5: 28.63s, train acc=0.13, train loss=2.28, validation acc=0.13, validation loss=2.28
# Epoch 6: 33.34s, train acc=0.16, train loss=2.27, validation acc=0.16, validation loss=2.27
# Epoch 7: 40.53s, train acc=0.19, train loss=2.27, validation acc=0.18, validation loss=2.27
# Epoch 8: 45.20s, train acc=0.21, train loss=2.26, validation acc=0.21, validation loss=2.26
# Epoch 9: 49.91s, train acc=0.24, train loss=2.26, validation acc=0.24, validation loss=2.26
# Epoch 10: 57.29s, train acc=0.25, train loss=2.25, validation acc=0.24, validation loss=2.25
# Epoch 11: 61.99s, train acc=0.25, train loss=2.25, validation acc=0.25, validation loss=2.25
# Epoch 12: 68.31s, train acc=0.30, train loss=2.24, validation acc=0.29, validation loss=2.24
# Epoch 13: 73.98s, train acc=0.34, train loss=2.23, validation acc=0.33, validation loss=2.23
# Epoch 14: 78.74s, train acc=0.34, train loss=2.22, validation acc=0.34, validation loss=2.23
# Epoch 15: 86.28s, train acc=0.36, train loss=2.22, validation acc=0.35, validation loss=2.22
# Epoch 16: 90.97s, train acc=0.40, train loss=2.21, validation acc=0.40, validation loss=2.21
# Epoch 17: 95.91s, train acc=0.40, train loss=2.20, validation acc=0.40, validation loss=2.20
# Epoch 18: 102.72s, train acc=0.42, train loss=2.19, validation acc=0.42, validation loss=2.19
# Epoch 19: 107.35s, train acc=0.44, train loss=2.18, validation acc=0.44, validation loss=2.18
# Epoch 20: 114.45s, train acc=0.44, train loss=2.17, validation acc=0.44, validation loss=2.17
# Testing optimizer=momentum, activation=tanh, learning_rate=0.01
# Epoch 1: 6.70s, train acc=0.88, train loss=0.51, validation acc=0.87, validation loss=0.54
# Epoch 2: 15.76s, train acc=0.90, train loss=0.38, validation acc=0.89, validation loss=0.41
# Epoch 3: 22.33s, train acc=0.91, train loss=0.33, validation acc=0.90, validation loss=0.36
# Epoch 4: 31.51s, train acc=0.92, train loss=0.30, validation acc=0.90, validation loss=0.34
# Epoch 5: 38.11s, train acc=0.92, train loss=0.28, validation acc=0.91, validation loss=0.32
# Epoch 6: 47.40s, train acc=0.93, train loss=0.26, validation acc=0.91, validation loss=0.30
# Epoch 7: 53.98s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.29
# Epoch 8: 62.97s, train acc=0.93, train loss=0.23, validation acc=0.92, validation loss=0.28
# Epoch 9: 69.83s, train acc=0.94, train loss=0.22, validation acc=0.92, validation loss=0.27
# Epoch 10: 78.44s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.26
# Epoch 11: 85.48s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.25
# Epoch 12: 93.49s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.24
# Epoch 13: 101.16s, train acc=0.95, train loss=0.19, validation acc=0.93, validation loss=0.24
# Epoch 14: 108.42s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.23
# Epoch 15: 117.65s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 16: 124.15s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 17: 133.39s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 18: 139.88s, train acc=0.96, train loss=0.16, validation acc=0.94, validation loss=0.20
# Epoch 19: 149.09s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Epoch 20: 155.59s, train acc=0.96, train loss=0.14, validation acc=0.94, validation loss=0.20
# Testing optimizer=momentum, activation=tanh, learning_rate=0.001
# Epoch 1: 9.27s, train acc=0.69, train loss=1.58, validation acc=0.68, validation loss=1.59
# Epoch 2: 15.82s, train acc=0.77, train loss=1.18, validation acc=0.75, validation loss=1.20
# Epoch 3: 27.27s, train acc=0.80, train loss=0.96, validation acc=0.79, validation loss=0.98
# Epoch 4: 33.85s, train acc=0.82, train loss=0.82, validation acc=0.82, validation loss=0.84
# Epoch 5: 42.78s, train acc=0.84, train loss=0.72, validation acc=0.83, validation loss=0.75
# Epoch 6: 49.57s, train acc=0.85, train loss=0.66, validation acc=0.84, validation loss=0.68
# Epoch 7: 58.00s, train acc=0.86, train loss=0.60, validation acc=0.85, validation loss=0.63
# Epoch 8: 65.18s, train acc=0.86, train loss=0.56, validation acc=0.86, validation loss=0.59
# Epoch 9: 73.01s, train acc=0.87, train loss=0.53, validation acc=0.86, validation loss=0.56
# Epoch 10: 80.56s, train acc=0.87, train loss=0.50, validation acc=0.87, validation loss=0.53
# Epoch 11: 88.10s, train acc=0.88, train loss=0.48, validation acc=0.87, validation loss=0.51
# Epoch 12: 96.13s, train acc=0.88, train loss=0.46, validation acc=0.88, validation loss=0.49
# Epoch 13: 103.29s, train acc=0.89, train loss=0.44, validation acc=0.88, validation loss=0.48
# Epoch 14: 111.72s, train acc=0.89, train loss=0.43, validation acc=0.88, validation loss=0.46
# Epoch 15: 118.38s, train acc=0.89, train loss=0.42, validation acc=0.88, validation loss=0.45
# Epoch 16: 127.50s, train acc=0.89, train loss=0.41, validation acc=0.88, validation loss=0.44
# Epoch 17: 134.03s, train acc=0.90, train loss=0.40, validation acc=0.89, validation loss=0.43
# Epoch 18: 143.23s, train acc=0.90, train loss=0.39, validation acc=0.89, validation loss=0.42
# Epoch 19: 149.72s, train acc=0.90, train loss=0.38, validation acc=0.89, validation loss=0.41
# Epoch 20: 158.99s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.41
# Testing optimizer=momentum, activation=leaky_relu, learning_rate=0.01
# Epoch 1: 4.14s, train acc=0.87, train loss=0.49, validation acc=0.86, validation loss=0.52
# Epoch 2: 9.48s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 3: 14.83s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.35
# Epoch 4: 18.93s, train acc=0.92, train loss=0.28, validation acc=0.91, validation loss=0.32
# Epoch 5: 24.30s, train acc=0.92, train loss=0.26, validation acc=0.91, validation loss=0.30
# Epoch 6: 29.76s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.28
# Epoch 7: 33.91s, train acc=0.94, train loss=0.22, validation acc=0.92, validation loss=0.27
# Epoch 8: 39.29s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.25
# Epoch 9: 44.82s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.24
# Epoch 10: 48.94s, train acc=0.94, train loss=0.19, validation acc=0.93, validation loss=0.23
# Epoch 11: 54.49s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.22
# Epoch 12: 59.95s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 13: 64.19s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.20
# Epoch 14: 69.99s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.19
# Epoch 15: 75.20s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.19
# Epoch 16: 79.44s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.18
# Epoch 17: 85.73s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.18
# Epoch 18: 90.68s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 19: 95.08s, train acc=0.97, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 20: 102.12s, train acc=0.97, train loss=0.11, validation acc=0.96, validation loss=0.16
# Testing optimizer=momentum, activation=leaky_relu, learning_rate=0.001
# Epoch 1: 4.31s, train acc=0.52, train loss=2.11, validation acc=0.51, validation loss=2.11
# Epoch 2: 8.73s, train acc=0.68, train loss=1.78, validation acc=0.68, validation loss=1.78
# Epoch 3: 15.93s, train acc=0.76, train loss=1.32, validation acc=0.76, validation loss=1.33
# Epoch 4: 20.24s, train acc=0.81, train loss=0.97, validation acc=0.79, validation loss=0.99
# Epoch 5: 24.60s, train acc=0.83, train loss=0.77, validation acc=0.82, validation loss=0.79
# Epoch 6: 31.83s, train acc=0.85, train loss=0.65, validation acc=0.83, validation loss=0.68
# Epoch 7: 36.14s, train acc=0.86, train loss=0.58, validation acc=0.85, validation loss=0.61
# Epoch 8: 41.02s, train acc=0.87, train loss=0.52, validation acc=0.86, validation loss=0.55
# Epoch 9: 47.06s, train acc=0.88, train loss=0.49, validation acc=0.86, validation loss=0.52
# Epoch 10: 51.40s, train acc=0.88, train loss=0.46, validation acc=0.87, validation loss=0.49
# Epoch 11: 57.22s, train acc=0.89, train loss=0.43, validation acc=0.87, validation loss=0.47
# Epoch 12: 62.44s, train acc=0.89, train loss=0.41, validation acc=0.88, validation loss=0.45
# Epoch 13: 66.69s, train acc=0.89, train loss=0.40, validation acc=0.88, validation loss=0.43
# Epoch 14: 72.67s, train acc=0.89, train loss=0.39, validation acc=0.88, validation loss=0.42
# Epoch 15: 77.56s, train acc=0.90, train loss=0.37, validation acc=0.88, validation loss=0.41
# Epoch 16: 81.79s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.40
# Epoch 17: 88.34s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.39
# Epoch 18: 92.72s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 19: 96.92s, train acc=0.90, train loss=0.34, validation acc=0.89, validation loss=0.38
# Epoch 20: 103.86s, train acc=0.91, train loss=0.34, validation acc=0.89, validation loss=0.38
# Testing optimizer=momentum, activation=selu, learning_rate=0.01
# Epoch 1: 6.33s, train acc=0.90, train loss=0.37, validation acc=0.88, validation loss=0.41
# Epoch 2: 14.90s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.35
# Epoch 3: 19.80s, train acc=0.92, train loss=0.28, validation acc=0.91, validation loss=0.33
# Epoch 4: 24.71s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.31
# Epoch 5: 32.46s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.30
# Epoch 6: 37.35s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.29
# Epoch 7: 44.55s, train acc=0.93, train loss=0.23, validation acc=0.92, validation loss=0.28
# Epoch 8: 49.65s, train acc=0.94, train loss=0.22, validation acc=0.92, validation loss=0.27
# Epoch 9: 54.51s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.26
# Epoch 10: 62.32s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.25
# Epoch 11: 67.18s, train acc=0.95, train loss=0.19, validation acc=0.93, validation loss=0.24
# Epoch 12: 74.04s, train acc=0.95, train loss=0.18, validation acc=0.93, validation loss=0.24
# Epoch 13: 79.54s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.23
# Epoch 14: 84.51s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.22
# Epoch 15: 92.16s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 16: 97.08s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.21
# Epoch 17: 103.84s, train acc=0.96, train loss=0.14, validation acc=0.94, validation loss=0.20
# Epoch 18: 109.40s, train acc=0.96, train loss=0.14, validation acc=0.94, validation loss=0.20
# Epoch 19: 114.32s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.19
# Epoch 20: 122.29s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.19
# Testing optimizer=momentum, activation=selu, learning_rate=0.001
# Epoch 1: 4.98s, train acc=0.78, train loss=1.04, validation acc=0.76, validation loss=1.06
# Epoch 2: 11.76s, train acc=0.83, train loss=0.73, validation acc=0.82, validation loss=0.76
# Epoch 3: 17.22s, train acc=0.86, train loss=0.60, validation acc=0.84, validation loss=0.63
# Epoch 4: 22.14s, train acc=0.87, train loss=0.52, validation acc=0.86, validation loss=0.56
# Epoch 5: 29.92s, train acc=0.88, train loss=0.47, validation acc=0.87, validation loss=0.51
# Epoch 6: 34.84s, train acc=0.88, train loss=0.44, validation acc=0.87, validation loss=0.48
# Epoch 7: 41.97s, train acc=0.89, train loss=0.42, validation acc=0.88, validation loss=0.46
# Epoch 8: 46.89s, train acc=0.89, train loss=0.40, validation acc=0.88, validation loss=0.44
# Epoch 9: 51.87s, train acc=0.90, train loss=0.38, validation acc=0.88, validation loss=0.42
# Epoch 10: 59.52s, train acc=0.90, train loss=0.37, validation acc=0.89, validation loss=0.41
# Epoch 11: 64.58s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.40
# Epoch 12: 72.23s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 13: 77.20s, train acc=0.90, train loss=0.34, validation acc=0.89, validation loss=0.39
# Epoch 14: 82.50s, train acc=0.91, train loss=0.34, validation acc=0.89, validation loss=0.38
# Epoch 15: 89.19s, train acc=0.91, train loss=0.33, validation acc=0.89, validation loss=0.37
# Epoch 16: 94.11s, train acc=0.91, train loss=0.33, validation acc=0.90, validation loss=0.37
# Epoch 17: 101.85s, train acc=0.91, train loss=0.32, validation acc=0.90, validation loss=0.36
# Epoch 18: 106.79s, train acc=0.91, train loss=0.32, validation acc=0.90, validation loss=0.36
# Epoch 19: 112.60s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.36
# Epoch 20: 119.09s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.35
# Testing optimizer=momentum, activation=elu, learning_rate=0.01
# Epoch 1: 4.83s, train acc=0.88, train loss=0.46, validation acc=0.87, validation loss=0.49
# Epoch 2: 12.44s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.39
# Epoch 3: 17.34s, train acc=0.91, train loss=0.32, validation acc=0.90, validation loss=0.36
# Epoch 4: 22.82s, train acc=0.92, train loss=0.30, validation acc=0.90, validation loss=0.34
# Epoch 5: 29.47s, train acc=0.92, train loss=0.28, validation acc=0.91, validation loss=0.32
# Epoch 6: 34.40s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.32
# Epoch 7: 41.95s, train acc=0.93, train loss=0.26, validation acc=0.91, validation loss=0.30
# Epoch 8: 46.85s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.29
# Epoch 9: 52.20s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.28
# Epoch 10: 59.04s, train acc=0.93, train loss=0.23, validation acc=0.92, validation loss=0.27
# Epoch 11: 63.96s, train acc=0.94, train loss=0.22, validation acc=0.92, validation loss=0.26
# Epoch 12: 72.17s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.25
# Epoch 13: 77.02s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.25
# Epoch 14: 82.86s, train acc=0.95, train loss=0.19, validation acc=0.93, validation loss=0.24
# Epoch 15: 89.16s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.23
# Epoch 16: 94.18s, train acc=0.95, train loss=0.18, validation acc=0.93, validation loss=0.23
# Epoch 17: 101.89s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.22
# Epoch 18: 106.84s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.21
# Epoch 19: 112.80s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.21
# Epoch 20: 121.77s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Testing optimizer=momentum, activation=elu, learning_rate=0.001
# Epoch 1: 6.18s, train acc=0.68, train loss=1.71, validation acc=0.68, validation loss=1.71
# Epoch 2: 12.33s, train acc=0.77, train loss=1.23, validation acc=0.76, validation loss=1.24
# Epoch 3: 17.27s, train acc=0.81, train loss=0.93, validation acc=0.80, validation loss=0.95
# Epoch 4: 24.96s, train acc=0.83, train loss=0.75, validation acc=0.82, validation loss=0.78
# Epoch 5: 29.89s, train acc=0.85, train loss=0.64, validation acc=0.84, validation loss=0.67
# Epoch 6: 35.92s, train acc=0.86, train loss=0.57, validation acc=0.85, validation loss=0.61
# Epoch 7: 41.96s, train acc=0.87, train loss=0.52, validation acc=0.86, validation loss=0.56
# Epoch 8: 46.82s, train acc=0.87, train loss=0.49, validation acc=0.86, validation loss=0.52
# Epoch 9: 54.56s, train acc=0.88, train loss=0.46, validation acc=0.87, validation loss=0.50
# Epoch 10: 59.46s, train acc=0.88, train loss=0.44, validation acc=0.87, validation loss=0.47
# Epoch 11: 64.92s, train acc=0.89, train loss=0.42, validation acc=0.87, validation loss=0.46
# Epoch 12: 71.29s, train acc=0.89, train loss=0.40, validation acc=0.88, validation loss=0.44
# Epoch 13: 76.27s, train acc=0.89, train loss=0.39, validation acc=0.88, validation loss=0.43
# Epoch 14: 83.78s, train acc=0.89, train loss=0.38, validation acc=0.88, validation loss=0.42
# Epoch 15: 88.74s, train acc=0.89, train loss=0.37, validation acc=0.88, validation loss=0.41
# Epoch 16: 94.46s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.41
# Epoch 17: 100.89s, train acc=0.90, train loss=0.36, validation acc=0.89, validation loss=0.40
# Epoch 18: 105.91s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 19: 113.61s, train acc=0.90, train loss=0.35, validation acc=0.89, validation loss=0.39
# Epoch 20: 118.59s, train acc=0.90, train loss=0.34, validation acc=0.89, validation loss=0.38
# Testing optimizer=adam, activation=relu, learning_rate=0.01
# Epoch 1: 7.65s, train acc=0.97, train loss=0.10, validation acc=0.95, validation loss=0.15
# Epoch 2: 13.36s, train acc=0.98, train loss=0.06, validation acc=0.96, validation loss=0.12
# Epoch 3: 18.87s, train acc=0.98, train loss=0.05, validation acc=0.97, validation loss=0.11
# Epoch 4: 26.59s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.11
# Epoch 5: 31.89s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.13
# Epoch 6: 40.03s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.14
# Epoch 7: 45.25s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.11
# Epoch 8: 54.22s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.13
# Epoch 9: 60.87s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.13
# Epoch 10: 70.07s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.14
# Epoch 11: 76.48s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.15
# Epoch 12: 85.57s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.17
# Epoch 13: 92.30s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.16
# Epoch 14: 101.61s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.16
# Epoch 15: 109.17s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.17
# Epoch 16: 117.38s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.15
# Epoch 17: 125.80s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.15
# Epoch 18: 133.00s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.17
# Epoch 19: 142.26s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.21
# Epoch 20: 149.19s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.17
# Testing optimizer=adam, activation=relu, learning_rate=0.001
# ...
# Epoch 15: 106.75s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.12
# Epoch 16: 115.30s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.11
# Epoch 17: 121.22s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.11
# Epoch 18: 129.64s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.11
# Epoch 19: 135.50s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.10
# Epoch 20: 143.83s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.10
# Testing optimizer=adam, activation=tanh, learning_rate=0.01
# Epoch 1: 7.73s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 2: 19.88s, train acc=0.98, train loss=0.08, validation acc=0.96, validation loss=0.14
# Epoch 3: 27.99s, train acc=0.98, train loss=0.07, validation acc=0.96, validation loss=0.14
# Epoch 4: 37.53s, train acc=0.98, train loss=0.05, validation acc=0.96, validation loss=0.13
# Epoch 5: 47.66s, train acc=0.99, train loss=0.05, validation acc=0.96, validation loss=0.13
# Epoch 6: 55.45s, train acc=0.99, train loss=0.05, validation acc=0.96, validation loss=0.13
# Epoch 7: 65.91s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.13
# Epoch 8: 75.73s, train acc=0.98, train loss=0.05, validation acc=0.96, validation loss=0.15
# Epoch 9: 83.38s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.13
# Epoch 10: 93.80s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.13
# Epoch 11: 102.01s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.13
# Epoch 12: 111.43s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.14
# Epoch 13: 122.16s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.14
# Epoch 14: 130.00s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.15
# Epoch 15: 140.71s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.14
# Epoch 16: 150.93s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.13
# Epoch 17: 158.90s, train acc=0.99, train loss=0.03, validation acc=0.96, validation loss=0.16
# Epoch 18: 169.52s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.15
# Epoch 19: 179.82s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.15
# Epoch 20: 187.77s, train acc=0.99, train loss=0.03, validation acc=0.96, validation loss=0.16
# Testing optimizer=adam, activation=tanh, learning_rate=0.001
# Epoch 1: 10.43s, train acc=0.95, train loss=0.18, validation acc=0.93, validation loss=0.23
# Epoch 2: 20.84s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.18
# Epoch 3: 28.70s, train acc=0.97, train loss=0.10, validation acc=0.95, validation loss=0.15
# Epoch 4: 39.47s, train acc=0.98, train loss=0.09, validation acc=0.96, validation loss=0.14
# Epoch 5: 48.57s, train acc=0.98, train loss=0.07, validation acc=0.96, validation loss=0.13
# Epoch 6: 56.85s, train acc=0.98, train loss=0.06, validation acc=0.96, validation loss=0.12
# Epoch 7: 67.44s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.11
# Epoch 8: 75.86s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.10
# Epoch 9: 85.25s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 10: 96.06s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 11: 104.09s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.10
# Epoch 12: 114.22s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.10
# Epoch 13: 124.79s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.10
# Epoch 14: 132.54s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.10
# Epoch 15: 142.94s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.10
# Epoch 16: 152.48s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.10
# Epoch 17: 160.15s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.10
# Epoch 18: 170.73s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.10
# Epoch 19: 179.23s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.10
# Epoch 20: 189.79s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.11
# Testing optimizer=adam, activation=leaky_relu, learning_rate=0.01
# Epoch 1: 5.96s, train acc=0.97, train loss=0.08, validation acc=0.96, validation loss=0.13
# Epoch 2: 13.07s, train acc=0.98, train loss=0.06, validation acc=0.96, validation loss=0.13
# Epoch 3: 18.78s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.11
# Epoch 4: 26.82s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.12
# Epoch 5: 32.06s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.13
# Epoch 6: 40.16s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.12
# Epoch 7: 45.45s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.12
# Epoch 8: 52.47s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.13
# Epoch 9: 58.52s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.13
# Epoch 10: 63.96s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.16
# Epoch 11: 72.15s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.15
# Epoch 12: 77.54s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.16
# Epoch 13: 85.73s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.16
# Epoch 14: 91.04s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.16
# Epoch 15: 99.00s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.16
# Epoch 16: 104.41s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.19
# Epoch 17: 110.68s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.17
# Epoch 18: 117.63s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.17
# Epoch 19: 123.06s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.21
# Epoch 20: 131.19s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.18
# Testing optimizer=adam, activation=leaky_relu, learning_rate=0.001
# Epoch 1: 5.51s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.21
# Epoch 2: 13.44s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 3: 18.84s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.14
# Epoch 4: 27.41s, train acc=0.98, train loss=0.08, validation acc=0.96, validation loss=0.13
# Epoch 5: 32.89s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.12
# Epoch 6: 40.67s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.12
# Epoch 7: 46.43s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.11
# Epoch 8: 52.09s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.10
# Epoch 9: 59.74s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.10
# Epoch 10: 65.19s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 11: 73.55s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 12: 78.97s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.10
# Epoch 13: 87.19s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.10
# Epoch 14: 92.79s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.10
# Epoch 15: 100.94s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.10
# Epoch 16: 106.38s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.11
# Epoch 17: 112.13s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.11
# Epoch 18: 119.62s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.10
# Epoch 19: 124.97s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.10
# Epoch 20: 133.18s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.10
# Testing optimizer=adam, activation=selu, learning_rate=0.01
# Epoch 1: 6.10s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 2: 15.13s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.12
# Epoch 3: 21.26s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.11
# Epoch 4: 29.98s, train acc=0.98, train loss=0.05, validation acc=0.96, validation loss=0.13
# Epoch 5: 35.99s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.12
# Epoch 6: 44.82s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.13
# Epoch 7: 50.83s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.13
# Epoch 8: 59.19s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.14
# Epoch 9: 65.16s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.15
# Epoch 10: 74.03s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.15
# Epoch 11: 82.38s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.17
# Epoch 12: 91.26s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.13
# Epoch 13: 97.31s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.15
# Epoch 14: 106.29s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.17
# Epoch 15: 112.30s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.19
# Epoch 16: 121.00s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.17
# Epoch 17: 127.10s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.17
# Epoch 18: 135.95s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.19
# Epoch 19: 142.04s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.21
# Epoch 20: 150.50s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.20
# Testing optimizer=adam, activation=selu, learning_rate=0.001
# Epoch 1: 6.09s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.25
# Epoch 2: 15.26s, train acc=0.96, train loss=0.15, validation acc=0.94, validation loss=0.20
# Epoch 3: 21.81s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 4: 30.31s, train acc=0.97, train loss=0.10, validation acc=0.95, validation loss=0.16
# Epoch 5: 36.89s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.14
# Epoch 6: 45.34s, train acc=0.98, train loss=0.08, validation acc=0.96, validation loss=0.14
# Epoch 7: 52.19s, train acc=0.98, train loss=0.07, validation acc=0.96, validation loss=0.13
# Epoch 8: 60.11s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.12
# Epoch 9: 67.06s, train acc=0.98, train loss=0.05, validation acc=0.97, validation loss=0.12
# Epoch 10: 75.08s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.12
# Epoch 11: 82.26s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.11
# Epoch 12: 90.17s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 13: 97.72s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 14: 105.13s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 15: 112.83s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 16: 120.10s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.11
# Epoch 17: 127.63s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.11
# Epoch 18: 135.11s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.11
# Epoch 19: 142.43s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.11
# Epoch 20: 149.76s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.12
# Testing optimizer=adam, activation=elu, learning_rate=0.01
# Epoch 1: 7.10s, train acc=0.97, train loss=0.08, validation acc=0.96, validation loss=0.14
# Epoch 2: 14.28s, train acc=0.98, train loss=0.06, validation acc=0.96, validation loss=0.13
# Epoch 3: 21.01s, train acc=0.98, train loss=0.05, validation acc=0.97, validation loss=0.13
# Epoch 4: 28.65s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 5: 34.64s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 6: 43.23s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.11
# Epoch 7: 49.31s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.13
# Epoch 8: 58.02s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.13
# Epoch 9: 64.08s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.14
# Epoch 10: 72.91s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.14
# Epoch 11: 78.82s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.13
# Epoch 12: 87.42s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.16
# Epoch 13: 93.41s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.16
# Epoch 14: 102.03s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.19
# Epoch 15: 108.12s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.18
# Epoch 16: 116.89s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.14
# Epoch 17: 122.92s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.19
# Epoch 18: 131.64s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.18
# Epoch 19: 141.67s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.19
# Epoch 20: 148.59s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.20
# Testing optimizer=adam, activation=elu, learning_rate=0.001
# Epoch 1: 7.18s, train acc=0.95, train loss=0.19, validation acc=0.93, validation loss=0.24
# Epoch 2: 14.29s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.18
# Epoch 3: 21.58s, train acc=0.97, train loss=0.11, validation acc=0.95, validation loss=0.16
# Epoch 4: 28.73s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.15
# Epoch 5: 35.61s, train acc=0.98, train loss=0.08, validation acc=0.96, validation loss=0.14
# Epoch 6: 43.30s, train acc=0.98, train loss=0.07, validation acc=0.96, validation loss=0.12
# Epoch 7: 50.79s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.12
# Epoch 8: 58.28s, train acc=0.98, train loss=0.05, validation acc=0.97, validation loss=0.11
# Epoch 9: 64.94s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.11
# Epoch 10: 72.91s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.10
# Epoch 11: 79.30s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.11
# Epoch 12: 87.57s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 13: 94.57s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 14: 102.84s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 15: 109.91s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.10
# Epoch 16: 118.01s, train acc=1.00, train loss=0.02, validation acc=0.97, validation loss=0.10
# Epoch 17: 124.83s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.10
# Epoch 18: 132.98s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.10
# Epoch 19: 140.08s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.10
# Epoch 20: 147.99s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.11

# %%
best_result = max(results, key=lambda x: x['validation_accuracy'])
print("\nBest Configuration:")
print(f"Optimizer: {best_result['optimizer']}")
print(f"Activation: {best_result['activation']}")
print(f"Learning Rate: {best_result['learning_rate']}")
print(f"Validation Accuracy: {best_result['validation_accuracy']:.4f}")
# Out:
# Best Configuration:
# Optimizer: adam
# Activation: leaky_relu
# Learning Rate: 0.001
# Validation Accuracy: 0.9760

# %% [markdown]
# # MLP as function Approximator
# We know that a MLP with one hidden layer could  approximate any smooth function! <br> Here you will manually fit a sine function using ReLU activation. <br>You need to set the correct weights on ReLUs so the linear combination approximates the desired function.

# %%
def relu_approximation(input_data, target_labels):
    """
    Args:
      input_data: torch.tensor
        Input training data
      target_labels: torch.tensor
        Ground truth labels for training data

    Returns:
      activation_map: torch.tensor
        ReLU activations computed across the x-axis
      predicted_labels: torch.tensor
        Estimated labels or class predictions
        Derived from weighted sum of ReLU activations along the x-axis
      x_points: torch.tensor
        Points along the x-axis
    """
    ##############################---TODO---##############################
    # Number of ReLU units
    num_relus = input_data.shape[0] - 1

    # Generate dense x-axis points for interpolation
    x_points = torch.linspace(torch.min(input_data), torch.max(input_data), 1000)

    # Compute bias for ReLU units
    biases = input_data.squeeze()

    # Initialize activation map to store ReLU activations
    activation_map = torch.zeros(num_relus, x_points.shape[0])

    for relu_idx in range(num_relus):
        activation_map[relu_idx, :] = torch.relu(x_points - biases[relu_idx])

    ## WEIGHTED SUM OF RELUS

    relu_weights = torch.zeros(num_relus)
    previous_slope = 0
    for j in range(num_relus):
        current_slope = (target_labels[j + 1] - target_labels[j]) / (input_data[j + 1] - input_data[j])
        relu_weights[j] = current_slope - previous_slope
        previous_slope = current_slope

    # Compute predicted labels as weighted sum of ReLU activations
    predicted_labels = relu_weights @ activation_map
    ##############################---TODO---##############################

    return predicted_labels, activation_map, x_points


# Generate synthetic training data using sine function
num_samples = 10
input_data = torch.linspace(0, 2 * np.pi, num_samples).view(-1, 1)
target_labels = torch.sin(input_data)

predicted_output, activation_map, x_points = relu_approximation(input_data, target_labels)
plot_function_apx(x_points, activation_map, predicted_output)

# %% [markdown]
# # Depth vs. Width
# Here we wanna see the effect of width vs. depth on a classification task.First you are going to implement MLP again; But with 2 differences: <br>
#
# 1.   It is general purpose (i.e. works for desired depth and activation functions)
# 2.   You will implement it using pytorch

# %%
class MLP_pytorch(nn.Module):
  """
  Simulate MLP Network
  """

  def __init__(self, activation_fn, input_feature_num, hidden_unit_nums, output_feature_num):
    """
    Initialize MLP Network parameters

    Args:
      activation_fn: string
        Activation function
      input_feature_num: int
        Number of input features
      hidden_unit_nums: list
        Number of units per hidden layer. List of integers
      output_feature_num: int
        Number of output features

    Returns:
      Nothing
    """
    super(MLP_pytorch, self).__init__()
    self.input_feature_num = input_feature_num
    self.mlp = nn.Sequential()

    in_num = input_feature_num
    ##############################---TODO---##############################
    for i, num_units in enumerate(hidden_unit_nums):
            self.mlp.add_module(f"Linear_{i+1}", nn.Linear(in_num, num_units))
            self.mlp.add_module(f"Activation_{i+1}", activation_fn)
            in_num = num_units
    out_layer = nn.Linear(in_num, output_feature_num)
    self.mlp.add_module('Output_Linear', out_layer)
    ##############################---TODO---##############################

  def forward(self, x):
    """
    Simulate forward pass of MLP Network

    Args:
      x: torch.tensor
        Input data

    Returns:
      logits: Instance of MLP
        Forward pass of MLP
    """
    # Reshape inputs to (batch_size, input_feature_num)
    x = x.view(-1, self.input_feature_num)
    logits = self.mlp(x) # forward pass

    return logits

# %% [markdown]
# Now let's make a spiral dataset that follows this formula:
# \begin{equation}
# \begin{array}{c}
# X_{k}(t)=t\left(\begin{array}{c}
# \sin \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right) \\
# \cos \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right)
# \end{array}\right)
# \end{array}, \quad 0 \leq t \leq 1, \quad k=1, \ldots, K
# \end{equation}
#
# Run cell below to create the data and load it as tensors.

# %%
# @title Data Loader
K = 4
sigma = 0.4
N = 1000
t = torch.linspace(0, 1, N)
X = torch.zeros(K*N, 2)
y = torch.zeros(K*N)
for k in range(K):
  X[k*N:(k+1)*N, 0] = t*(torch.sin(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  X[k*N:(k+1)*N, 1] = t*(torch.cos(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  y[k*N:(k+1)*N] = k


X_test, y_test, X_train, y_train = shuffle_and_split_data(X, y, seed=SEED)

# DataLoader with random seed
batch_size = 128
g_seed = torch.Generator()
g_seed.manual_seed(SEED)

test_data = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_data, batch_size=batch_size,
                         shuffle=False, num_workers=0,
                         worker_init_fn=seed_worker,
                         generator=g_seed,
                         )

train_data = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_data,
                          batch_size=batch_size,
                          drop_last=True,
                          shuffle=True,
                          worker_init_fn=seed_worker,
                          generator=g_seed,
                          )

# %% [markdown]
# Now we will add more polynomial features to the dataset to make the first layer wider. Afterwards, train a single linear layer. We could use the same MLP network with no hidden layers (though it would not be called an MLP anymore!).
#
# Add polynomial terms up to $P=50$ which means that for every $x_1^n x_2^m$ term, $n+m\leq P$. Total number of polynomial features up to $P$ follows this formula:
#
# \begin{equation}
# \text{# of terms} = \frac{(P+1)(P+2)}{2}
# \end{equation}
#
# Also, we don't need the polynomial term with degree zero (which is the constatnt term) since `nn.Linear` layers have bias terms. Therefore we will have one fewer polynomial feature.

# %%
from itertools import combinations_with_replacement
def polynomial_classifier(poly_degree, seed=0):
  """
  Helper function to run the polynomial classifier

  Args:
    poly_degree: int
      Degree of the polynomial
    seed: int
      A non-negative integer that defines the random state.

  Returns:
    num_features: int
      Number of features
  """

  def polynomial_features(poly_degree, X):
    """
    Function to define the number of polynomial features except the bias term

    Args:
      poly_degree: int
        Degree of the polynomial
      X: torch.tensor
        Input data

    Returns:
      num_features: int
        Number of features
      poly_X: torch.tensor
        Polynomial term
    """
    ##############################---TODO---##############################
    num_features = (poly_degree + 1) * (poly_degree + 2) // 2 - 1  # Exclude the constant term
    poly_X = torch.zeros(X.shape[0], num_features)

    feature_idx = 0
    for n in range(1, poly_degree + 1):
        for powers in combinations_with_replacement(range(X.shape[1]), n):
            poly_X[:, feature_idx] = torch.prod(X[:, powers], dim=1)
            feature_idx += 1

    return poly_X, num_features
    ##############################---TODO---##############################

  poly_X_test, num_features = polynomial_features(poly_degree, X_test)
  poly_X_train, _ = polynomial_features(poly_degree, X_train)

  batch_size = 128

  g_seed = torch.Generator()
  g_seed.manual_seed(seed)
  poly_test_data = TensorDataset(poly_X_test, y_test)
  poly_test_loader = DataLoader(poly_test_data,
                                batch_size=batch_size,
                                shuffle=False,
                                num_workers=1,
                                worker_init_fn=seed_worker,
                                generator=g_seed)

  poly_train_data = TensorDataset(poly_X_train, y_train)
  poly_train_loader = DataLoader(poly_train_data,
                                 batch_size=batch_size,
                                 shuffle=True,
                                 num_workers=1,
                                 worker_init_fn=seed_worker,
                                 generator=g_seed)

  # Defining a linear model using MLP class
  poly_net = MLP_pytorch('ReLU()', num_features, [], K)

  # Train and test
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(poly_net.parameters(), lr=1e-3)
  _, _ = train_test_classification(poly_net, criterion, optimizer,
                                   poly_train_loader, poly_test_loader,
                                   num_epochs=100)
  X_all = sample_grid()
  poly_X_all, _ = polynomial_features(poly_degree, X_all)
  y_pred = poly_net(poly_X_all)

  # Plot
  plot_decision_map(X_all.cpu(), y_pred.cpu(), X_test.cpu(), y_test.cpu())
  plt.show()

  return num_features

# %% [markdown]
# ### Train the network. How does it generalize?

# %%
seed_setter(seed=SEED)
max_poly_deg = 50
num_features = polynomial_classifier(max_poly_deg)
print(f'Number of features: {num_features}')
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 69.94
# Accuracy on the 800 testing samples: 69.12
# Number of features: 1325

# %% [markdown]
# Now create another instance of `MLP_pytorch` class having a hidden layer of 128 neurons and train it. Compare the result with the wide network. How does deeper model generalize? Is the decision boundaries ideal? Why?

# %%
##############################---TODO---##############################
seed_setter(SEED)
net2 = MLP_pytorch(
    activation_fn=nn.ReLU(),           # Activation function (ReLU)
    input_feature_num=2,               # Number of input features (2 for spiral dataset)
    hidden_unit_nums=[128],            # List of hidden layer units (e.g., 128 units in one hidden layer)
    output_feature_num=4              # Number of output features (4 classes, one per spiral)
)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net2.parameters(), lr=1e-3)
num_epochs = 100

_, _ = train_test_classification(net2, criterion, optimizer, train_loader,
                                 test_loader, num_epochs=num_epochs,
                                 training_plot=True)

X_all = sample_grid()
y_pred = net2(X_all).cpu()
plot_decision_map(X_all, y_pred, X_test, y_test)

##############################---TODO---##############################
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 97.75
# Accuracy on the 800 testing samples: 98.00

# %% [markdown]
# We can see The deeper model achieves much higher accuracy, both on the training and test sets, indicating better generalization to unseen data.
#
# The wide model struggles with the complexity of the data and likely underfits, while the deeper model captures the intricate decision boundaries and generalizes better.
#
# the decision boundaries learned by the deeper model are more ideal for the task at hand.The ideal decision boundaries can be achieved with a deeper model as it can capture the non-linear patterns more accurately and also model generalization is also good.
